# %%
import pandas as pd

# %%
SourceData = pd.read_csv('/Users/runminghuang/Documents/GitHub/capstone/datasets/sp500_final_data_5y.csv')[['symbol', 'date', 'volume', 'adjclose', 'Return', 'Sector', 'Industry']]
s
# Out:
#        symbol        date        open        high         low       close  \
# 0         BSX  2020-03-16   28.719999   29.230000   27.160000   27.549999
# 1         BSX  2020-03-17   28.100000   29.040001   26.340000   28.790001
# 2         BSX  2020-03-18   26.980000   27.700001   25.410000   27.240000
# 3         BSX  2020-03-19   26.740000   28.870001   25.510000   28.270000
# 4         BSX  2020-03-20   28.629999   28.780001   27.100000   27.240000
# ...       ...         ...         ...         ...         ...         ...
# 622199   ADSK  2025-03-10  256.609985  256.929993  246.309998  248.399994
# 622200   ADSK  2025-03-11  247.559998  254.380005  246.949997  250.850006
# 622201   ADSK  2025-03-12  254.500000  255.910004  250.110001  251.850006
# 622202   ADSK  2025-03-13  251.850006  252.669998  244.850006  246.929993
# 622203   ADSK  2025-03-14  248.990005  254.889999  248.990005  254.429993
#
#           volume    adjclose    Return  Transaction_Rate  Book_to_Market  \
# ...
