# %% [markdown]
# <a href="https://colab.research.google.com/github/george-lhj/Transfer_Learning_for_Stock_Prediction/blob/data-processing-signature-computing/Sig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install esig
# Out:
# Collecting esig
#   Downloading esig-1.0.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from esig) (1.26.4)
# Collecting pyrecombine (from esig)
#   Downloading pyrecombine-1.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting roughpy (from esig)
#   Downloading roughpy-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting numpy (from esig)
#   Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: intel_openmp in /usr/local/lib/python3.11/dist-packages (from pyrecombine->esig) (2025.0.4)
# Requirement already satisfied: intel-cmplr-lib-ur==2025.0.4 in /usr/local/lib/python3.11/dist-packages (from intel_openmp->pyrecombine->esig) (2025.0.4)
# Requirement already satisfied: umf==0.9.* in /usr/local/lib/python3.11/dist-packages (from intel-cmplr-lib-ur==2025.0.4->intel_openmp->pyrecombine->esig) (0.9.1)
# Requirement already satisfied: tcmlib==1.2 in /usr/local/lib/python3.11/dist-packages (from umf==0.9.*->intel-cmplr-lib-ur==2025.0.4->intel_openmp->pyrecombine->esig) (1.2.0)
# Downloading esig-1.0.0-py3-none-any.whl (19 kB)
# Downloading pyrecombine-1.0.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 29.2 MB/s eta 0:00:00
# Downloading numpy-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 35.0 MB/s eta 0:00:00
# Downloading roughpy-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 62.3 MB/s eta 0:00:00
# Installing collected packages: numpy, roughpy, pyrecombine, esig
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.2 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.2.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.2 which is incompatible.
# pytensor 2.26.4 requires numpy<2,>=1.17.0, but you have numpy 2.2.2 which is incompatible.
# langchain 0.3.16 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.2.2 which is incompatible.
# Successfully installed esig-1.0.0 numpy-2.2.2 pyrecombine-1.0.0 roughpy-0.2.0

# %%
import numpy as np
import esig
import pandas as pd
import itertools
from sklearn.decomposition import PCA

# %% [markdown]
# ## Data Import

# %%
x_train = pd.read_csv("/content/x_train_Lafd4AH.csv")
y_train = pd.read_csv("/content/y_train_JQU4vbI.csv")
x_test = pd.read_csv("/content/x_test_c7ETL4q.csv")
y_test = pd.read_csv("/content/test_rand.csv")

# %%
x_train
# Out:
#             ID  DATE  STOCK  INDUSTRY  INDUSTRY_GROUP  SECTOR  SUB_INDUSTRY  \
# 0            0     0      2        18               5       3            44
# 1            1     0      3        43              15       6           104
# 2            2     0      4        57              20       8           142
# 3            3     0      8         1               1       1             2
# 4            4     0     14        36              12       5            92
# ...        ...   ...    ...       ...             ...     ...           ...
# 418590  418590   223   5703        32              10       4            77
# 418591  418591   223   5705        35              12       5            91
# 418592  418592   223   5709         2               1       1             5
# 418593  418593   223   5710        33              10       4            83
# 418594  418594   223   5713        26               7       4            60
#
#            RET_1  VOLUME_1     RET_2  ...    RET_16  VOLUME_16    RET_17  \
# 0      -0.015748  0.147931 -0.015504  ...  0.059459   0.630899  0.003254
# 1       0.003984       NaN -0.090580  ...  0.015413        NaN  0.003774
# 2       0.000440 -0.096282 -0.058896  ...  0.008964  -0.010336 -0.017612
# 3       0.031298 -0.429540  0.007756  ... -0.031769   0.012105  0.033824
# 4       0.027273 -0.847155 -0.039302  ... -0.038461  -0.277083 -0.012659
# ...          ...       ...       ...  ...       ...        ...       ...
# 418590  0.021843 -0.217823 -0.021703  ...  0.003160  -0.161543  0.007785
# 418591 -0.006920 -0.375251  0.000000  ...  0.007169  -0.955492 -0.016221
# 418592  0.021869 -0.978856 -0.005929  ...  0.001110  -0.476550  0.029714
# 418593  0.012248 -0.627169  0.010925  ...  0.007450  -0.210079  0.023729
# 418594  0.076162 -1.325986 -0.000988  ...  0.035503   0.277896 -0.037037
#
#         VOLUME_17    RET_18  VOLUME_18    RET_19  VOLUME_19    RET_20  \
# 0       -0.379412  0.008752  -0.110597 -0.012959   0.174521 -0.002155
# 1             NaN -0.018518        NaN -0.028777        NaN -0.034722
# 2       -0.354333 -0.006562  -0.519391 -0.012101  -0.356157 -0.006867
# 3       -0.290178 -0.001468  -0.663834 -0.013520  -0.562126 -0.036745
# 4        0.139086  0.004237  -0.017547  0.004256   0.579510 -0.040817
# ...           ...       ...        ...       ...        ...       ...
# 418590  -0.141487  0.008205  -0.268215 -0.058448   0.057577  0.031174
# 418591  -0.171172  0.007819   1.540184 -0.015396  -0.502337 -0.011073
# 418592  -0.385972 -0.069148   1.780169 -0.082927   1.581453  0.098607
# 418593   0.813948  0.026087  -0.868576 -0.051155   0.371052  0.041238
# 418594   0.056942 -0.001896  -0.521932 -0.008366  -0.377668  0.003679
#
#         VOLUME_20
# 0       -0.000937
# 1             NaN
# 2       -0.308868
# 3       -0.631458
# 4        0.802806
# ...           ...
# 418590  -0.163350
# 418591   0.632885
# 418592   6.956960
# 418593   0.045695
# 418594  -1.393662
#
# [418595 rows x 47 columns]

# %%
# Load stock data
df = x_train.sort_values(by=['STOCK', 'DATE']).reset_index(drop=True)
df
# Out:
#             ID  DATE  STOCK  INDUSTRY  INDUSTRY_GROUP  SECTOR  SUB_INDUSTRY  \
# 0         2377     1      0        37              12       5            94
# 1         5198     4      0        37              12       5            94
# 2         8017     5      0        37              12       5            94
# 3        20826    11      0        37              12       5            94
# 4        33843    21      0        37              12       5            94
# ...        ...   ...    ...       ...             ...     ...           ...
# 418590  391556   206   5716        50              17       7           114
# 418591  394490   208   5716        50              17       7           114
# 418592  400150   210   5716        50              17       7           114
# 418593  403129   211   5716        50              17       7           114
# 418594  416228   221   5716        50              17       7           114
#
#            RET_1  VOLUME_1     RET_2  ...    RET_16  VOLUME_16    RET_17  \
# 0      -0.005967  0.136699  0.009031  ... -0.009219  -0.493354 -0.007660
# 1       0.001348 -0.269520  0.011100  ... -0.000762  -0.313575  0.007867
# 2      -0.014405  0.192655  0.003614  ...  0.002742  -0.367499 -0.005843
# 3       0.008938  0.430916  0.002662  ...  0.009097   0.023598  0.011266
# 4      -0.006523 -0.060371 -0.007632  ... -0.014461  -0.337686 -0.007224
# ...          ...       ...       ...  ...       ...        ...       ...
# 418590  0.029552 -0.075091 -0.001428  ...  0.024553   0.076480  0.017026
# 418591  0.008316  0.028099 -0.006688  ...  0.020970   0.090287  0.002887
# 418592 -0.004633 -0.173518  0.001687  ... -0.024517   0.695373 -0.015320
# 418593  0.010883  0.172313  0.008844  ...  0.005832  -0.045512 -0.008823
# 418594 -0.021391 -0.176100  0.024657  ... -0.062398  -0.565365 -0.002706
#
#         VOLUME_17    RET_18  VOLUME_18    RET_19  VOLUME_19    RET_20  \
# 0       -0.585497 -0.001063  -0.351363  0.005127  -0.324675 -0.019275
# 1        0.071338  0.007733  -0.405243 -0.003276  -0.424336 -0.010489
# 2       -0.405562  0.002930  -0.315935  0.010462  -0.474957 -0.003541
# 3        0.079711  0.019038  -0.230167 -0.000287  -0.312123  0.008682
# 4       -0.161117 -0.001461  -0.095494  0.012667   0.471895 -0.038752
# ...           ...       ...        ...       ...        ...       ...
# 418590   0.170516  0.002276  -0.106224 -0.034597   0.123750 -0.015676
# 418591  -0.050408  0.008736  -0.159294  0.027350  -0.022922  0.008186
# 418592  -0.149467 -0.035810  -0.262389  0.000896  -0.172450  0.008586
# 418593  -0.026153 -0.011428  -0.142636  0.011253  -0.224195  0.000609
# 418594  -0.227997  0.032402  -1.587177 -0.043803  -0.387343 -0.006897
#
#         VOLUME_20
# 0       -0.291751
# 1       -0.050591
# 2       -0.260130
# 3       -0.226628
# 4        1.532045
# ...           ...
# 418590  -0.228186
# 418591  -0.080569
# 418592  -0.482171
# 418593  -0.341878
# 418594  -0.467651
#
# [418595 rows x 47 columns]

# %% [markdown]
# plan：
# 1. NaN -> 0 or Mean of column of the stock
# 2. Feature Engineering: 40 rtn and vol dimension -> 10 rtn and vol dim (PCA or other means)  Or, use 1day 5day 20day rtn and vol
# 3. For each row, calculate the sig (dim=11, order 3)
# 4. Feature Engineering on the Sig outcome: 1464 dim -> 15 dim (Ridge regression/ Lasso)

# %% [markdown]
# ## Data Preprocess

# %%
# Fill NaN with 0
df = df.fillna(0)
# Keep only the selected columns
selected_columns = ['ID', 'DATE', 'STOCK'] + [col for col in df.columns if col.startswith(('RET_', 'VOLUME_'))]
df = df[selected_columns]
df
# Out:
#             ID  DATE  STOCK     RET_1  VOLUME_1     RET_2  VOLUME_2     RET_3  \
# 0         2377     1      0 -0.005967  0.136699  0.009031 -0.003109  0.008296
# 1         5198     4      0  0.001348 -0.269520  0.011100 -0.085622  0.012023
# 2         8017     5      0 -0.014405  0.192655  0.003614  0.353804  0.011156
# 3        20826    11      0  0.008938  0.430916  0.002662  0.175444  0.002490
# 4        33843    21      0 -0.006523 -0.060371 -0.007632 -0.037806  0.004756
# ...        ...   ...    ...       ...       ...       ...       ...       ...
# 418590  391556   206   5716  0.029552 -0.075091 -0.001428 -0.026934  0.007191
# 418591  394490   208   5716  0.008316  0.028099 -0.006688 -0.169174  0.018022
# 418592  400150   210   5716 -0.004633 -0.173518  0.001687 -0.231339  0.004663
# 418593  403129   211   5716  0.010883  0.172313  0.008844 -0.198001  0.001833
# 418594  416228   221   5716 -0.021391 -0.176100  0.024657 -0.189710  0.006064
#
#         VOLUME_3     RET_4  ...    RET_16  VOLUME_16    RET_17  VOLUME_17  \
# 0       0.015042  0.002638  ... -0.009219  -0.493354 -0.007660  -0.585497
# 1      -0.324746 -0.016477  ... -0.000762  -0.313575  0.007867   0.071338
# 2      -0.133228  0.000000  ...  0.002742  -0.367499 -0.005843  -0.405562
# 3      -0.083462  0.014896  ...  0.009097   0.023598  0.011266   0.079711
# 4      -0.251701  0.005466  ... -0.014461  -0.337686 -0.007224  -0.161117
# ...          ...       ...  ...       ...        ...       ...        ...
# 418590 -0.150806  0.014591  ...  0.024553   0.076480  0.017026   0.170516
# 418591  0.260882  0.004829  ...  0.020970   0.090287  0.002887  -0.050408
# 418592  0.044563  0.020771  ... -0.024517   0.695373 -0.015320  -0.149467
# 418593 -0.192868  0.006767  ...  0.005832  -0.045512 -0.008823  -0.026153
# 418594 -0.296746 -0.055208  ... -0.062398  -0.565365 -0.002706  -0.227997
#
#           RET_18  VOLUME_18    RET_19  VOLUME_19    RET_20  VOLUME_20
# 0      -0.001063  -0.351363  0.005127  -0.324675 -0.019275  -0.291751
# 1       0.007733  -0.405243 -0.003276  -0.424336 -0.010489  -0.050591
# 2       0.002930  -0.315935  0.010462  -0.474957 -0.003541  -0.260130
# 3       0.019038  -0.230167 -0.000287  -0.312123  0.008682  -0.226628
# 4      -0.001461  -0.095494  0.012667   0.471895 -0.038752   1.532045
# ...          ...        ...       ...        ...       ...        ...
# 418590  0.002276  -0.106224 -0.034597   0.123750 -0.015676  -0.228186
# 418591  0.008736  -0.159294  0.027350  -0.022922  0.008186  -0.080569
# 418592 -0.035810  -0.262389  0.000896  -0.172450  0.008586  -0.482171
# 418593 -0.011428  -0.142636  0.011253  -0.224195  0.000609  -0.341878
# 418594  0.032402  -1.587177 -0.043803  -0.387343 -0.006897  -0.467651
#
# [418595 rows x 43 columns]

# %% [markdown]
# ## Feature Engineering Using PCA

# %%
ret_cols = [col for col in df.columns if col.startswith('RET_')]
vol_cols = [col for col in df.columns if col.startswith('VOLUME_')]

# Apply PCA to returns
pca_ret = PCA(n_components=5)
ret_pca = pca_ret.fit_transform(df[ret_cols])
ret_pca_df = pd.DataFrame(data=ret_pca, columns=[f'PCA_RET_{i+1}' for i in range(5)], index=df.index)  # Keep original index

# Apply PCA to volume
pca_vol = PCA(n_components=5)
vol_pca = pca_vol.fit_transform(df[vol_cols])
vol_pca_df = pd.DataFrame(data=vol_pca, columns=[f'PCA_VOL_{i+1}' for i in range(5)], index=df.index)  # Keep original index

# Concatenate PCA results
df_pca = pd.concat([df[['ID', 'DATE', 'STOCK']], ret_pca_df, vol_pca_df], axis=1)
df_pca
# Out:
#             ID  DATE  STOCK  PCA_RET_1  PCA_RET_2  PCA_RET_3  PCA_RET_4  \
# 0         2377     1      0  -0.014258  -0.007401  -0.027476  -0.005828
# 1         5198     4      0  -0.004725  -0.001725  -0.001142  -0.006747
# 2         8017     5      0   0.000779  -0.003866  -0.008795   0.000896
# 3        20826    11      0   0.002867  -0.008982   0.006198   0.004372
# 4        33843    21      0  -0.001385  -0.003776   0.008496  -0.019039
# ...        ...   ...    ...        ...        ...        ...        ...
# 418590  391556   206   5716   0.013769  -0.014427   0.005998   0.012424
# 418591  394490   208   5716   0.009162   0.012654  -0.002195   0.015500
# 418592  400150   210   5716   0.005764   0.017102  -0.034786   0.012512
# 418593  403129   211   5716   0.009472  -0.004098  -0.023655   0.006036
# 418594  416228   221   5716   0.016391   0.005534   0.034057  -0.021932
#
#         PCA_RET_5  PCA_VOL_1  PCA_VOL_2  PCA_VOL_3  PCA_VOL_4  PCA_VOL_5
# 0        0.032285   0.837817  -0.337683   0.120331  -0.575671   0.416214
# 1        0.001001   0.058194  -0.650075  -0.514919   0.137769  -0.240635
# 2       -0.005832   0.746969  -0.386991  -0.192132   0.040193  -0.018479
# 3        0.002254   0.493443   0.008240  -0.138977   0.364540  -0.101550
# 4        0.002123  -0.508459   0.382084  -1.437075   0.041788   0.519180
# ...           ...        ...        ...        ...        ...        ...
# 418590   0.025532  -0.225391   0.342625   0.522349   0.218715  -0.282242
# 418591   0.008786  -0.040578   0.149366   0.100504   0.203370  -0.283302
# 418592   0.013068  -0.309019   0.218427   1.224077   0.566293  -0.577684
# 418593   0.005969   0.044986  -0.198227   0.053178   0.647204  -0.274329
# 418594   0.004607   0.657221  -1.309592   0.078055  -0.178634   0.485790
#
# [418595 rows x 13 columns]

# %% [markdown]
# ## Signature Computing

# %%
# Define signature computation parameters
n = 3  # Signature order
features = ['DATE',
            'PCA_RET_1', 'PCA_RET_2', 'PCA_RET_3', 'PCA_RET_4', 'PCA_RET_5',
            'PCA_VOL_1', 'PCA_VOL_2', 'PCA_VOL_3', 'PCA_VOL_4', 'PCA_VOL_5']
d = len(features)
signature_data = []

# %% [markdown]
# #### Test: Only select the first stock

# %%
first_stock_name = df_pca['STOCK'].unique()[0]
first_stock_df = df_pca[df_pca['STOCK'] == first_stock_name].sort_values(by="DATE")  # Ensure chronological order

# Extract relevant columns as time-series path
path = first_stock_df[features].values

# Compute the signature for this stock's path
signature = esig.stream2sig(path, n)
signature_list = list(signature)

# Generate feature interaction labels
multi_index_labels = ["Zeroth Level"]
level_counts = [0]
for level in range(1, n + 1):
    indices = list(itertools.product(range(d), repeat=level))  # Generate index sequences
    for idx in indices:
        term_label = '-'.join([features[i] for i in idx])  # Convert index to feature names
        multi_index_labels.append(term_label)
        level_counts.append(level)

# Ensure array sizes match
min_length = min(len(signature_list), len(multi_index_labels), len(level_counts))
signature_list = signature_list[:min_length]
multi_index_labels = multi_index_labels[:min_length]
level_counts = level_counts[:min_length]

# Store results with stock metadata
signature_data = []
for i in range(min_length):
    signature_data.append({
        'Stock': first_stock_name,
        'Signature Term': signature_list[i],
        'Order Level': level_counts[i],
        'Feature Interaction': multi_index_labels[i]
    })

# Convert to DataFrame and display
signature_df = pd.DataFrame(signature_data)
signature_df
# Out:
#       Stock  Signature Term  Order Level            Feature Interaction
# 0         0        1.000000            0                   Zeroth Level
# 1         0      220.000000            1                           DATE
# 2         0        0.020195            1                      PCA_RET_1
# 3         0        0.016815            1                      PCA_RET_2
# 4         0        0.020020            1                      PCA_RET_3
# ...     ...             ...          ...                            ...
# 1459      0        0.082426            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_1
# 1460      0        0.079573            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_2
# 1461      0       -0.097517            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_3
# 1462      0        0.057638            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_4
# 1463      0       -0.001322            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_5
#
# [1464 rows x 4 columns]

# %% [markdown]
# #### Compute signatures for all stocks

# %%
# Process each stock separately
for stock_id, stock_df in df_pca.groupby("STOCK"):
    stock_df = stock_df.sort_values(by="DATE")  # Ensure chronological order

    # Drop NaN values from selected features
    stock_df = stock_df.dropna(subset=features)

    # Ensure at least 2 rows exist before computing the signature
    if len(stock_df) < 2:
        print(f"Skipping stock {stock_id}: Not enough valid rows for signature computation.")
        continue

    # Extract relevant columns as time-series path
    path = stock_df[features].values  # Shape (time_steps, 11)

    # Compute the signature for this stock's path
    try:
        signature = esig.stream2sig(path, n)
        signature_list = list(signature)
    except ValueError as e:
        print(f"Skipping stock {stock_id} due to signature computation error: {e}")
        continue

    # Generate feature interaction labels
    multi_index_labels = ["Zeroth Level"]
    level_counts = [0]
    for level in range(1, n + 1):
        indices = list(itertools.product(range(d), repeat=level))  # Generate index sequences
        for idx in indices:
            term_label = '-'.join([features[i] for i in idx])  # Convert index to feature names
            multi_index_labels.append(term_label)
            level_counts.append(level)

    # Ensure array sizes match
    min_length = min(len(signature_list), len(multi_index_labels), len(level_counts))
    signature_list = signature_list[:min_length]
    multi_index_labels = multi_index_labels[:min_length]
    level_counts = level_counts[:min_length]

    # Store results with stock metadata
    for i in range(min_length):
        signature_data.append({
            'Stock': stock_id,
            'Signature Term': signature_list[i],
            'Order Level': level_counts[i],
            'Feature Interaction': multi_index_labels[i]
        })

# Convert to DataFrame and display
signature_df = pd.DataFrame(signature_data)
signature_df
# Out:
# Skipping stock 94 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 107 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 122 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 257 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 287 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 378 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 438 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 583 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 750: Not enough valid rows for signature computation.
# Skipping stock 839 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 1017 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 1126 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 1144: Not enough valid rows for signature computation.
# Skipping stock 1268 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 1473: Not enough valid rows for signature computation.
# Skipping stock 1576: Not enough valid rows for signature computation.
# Skipping stock 1756: Not enough valid rows for signature computation.
# Skipping stock 1766 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 1772 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 1881: Not enough valid rows for signature computation.
# Skipping stock 1885: Not enough valid rows for signature computation.
# Skipping stock 1962: Not enough valid rows for signature computation.
# Skipping stock 2102 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2450: Not enough valid rows for signature computation.
# Skipping stock 2455: Not enough valid rows for signature computation.
# Skipping stock 2461: Not enough valid rows for signature computation.
# Skipping stock 2462: Not enough valid rows for signature computation.
# Skipping stock 2463: Not enough valid rows for signature computation.
# Skipping stock 2469: Not enough valid rows for signature computation.
# Skipping stock 2475 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2480: Not enough valid rows for signature computation.
# Skipping stock 2483: Not enough valid rows for signature computation.
# Skipping stock 2485: Not enough valid rows for signature computation.
# Skipping stock 2486: Not enough valid rows for signature computation.
# Skipping stock 2487: Not enough valid rows for signature computation.
# Skipping stock 2489: Not enough valid rows for signature computation.
# Skipping stock 2500: Not enough valid rows for signature computation.
# Skipping stock 2506: Not enough valid rows for signature computation.
# Skipping stock 2509: Not enough valid rows for signature computation.
# Skipping stock 2510: Not enough valid rows for signature computation.
# Skipping stock 2513: Not enough valid rows for signature computation.
# Skipping stock 2516: Not enough valid rows for signature computation.
# Skipping stock 2517: Not enough valid rows for signature computation.
# Skipping stock 2518: Not enough valid rows for signature computation.
# Skipping stock 2531: Not enough valid rows for signature computation.
# Skipping stock 2541: Not enough valid rows for signature computation.
# Skipping stock 2731 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2732 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2842 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2890 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2896 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2921 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2950 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 2979 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3028 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3119 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3147 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3158 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3194 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3208 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3222 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3237 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3250 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3255 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3267 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3268 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3308 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3312 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3327 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3347 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3363 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3380 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3385 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3393 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3452 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3466 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3476 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3549 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3562 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3592 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3597 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3684 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3697 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3748 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3773 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3788 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3790 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3795 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3926 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3956 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 3967 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4009 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4088 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4127 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4150 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4171 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4179 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4232 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4313 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4356 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4374 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4451: Not enough valid rows for signature computation.
# Skipping stock 4487 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4490 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4507 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4528 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4610 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4655 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4677 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4689 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4857 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4892: Not enough valid rows for signature computation.
# Skipping stock 4918 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4935 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4962 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4963 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4985 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 4987 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5046 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5127 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5141 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5166 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5192 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5194 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5266 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5305 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5325 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5326 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5360 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5380 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5439 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5506 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5533 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
# Skipping stock 5604 due to signature computation error: Error occurred in /project/roughpy/src/streams/lie_increment_stream.cpp at line 183(pybind11::object lie_increment_stream_from_increments(pybind11::object, pybind11::kwargs)):
# mismatch between number of rows in data and number of indices
#          Stock  Signature Term  Order Level            Feature Interaction
# 0            0        1.000000            0                   Zeroth Level
# 1            0      220.000000            1                           DATE
# 2            0        0.020195            1                      PCA_RET_1
# 3            0        0.016815            1                      PCA_RET_2
# 4            0        0.020020            1                      PCA_RET_3
# ...        ...             ...          ...                            ...
# 7636219   5716        0.346560            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_1
# 7636220   5716        0.625354            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_2
# 7636221   5716        0.234473            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_3
# 7636222   5716       -1.212235            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_4
# 7636223   5716        0.357053            3  PCA_VOL_5-PCA_VOL_5-PCA_VOL_5
#
# [7636224 rows x 4 columns]
# Warning: total number of rows (7636224) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
signature_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
